# %%
import pandas as pd
from train import train

# %%
nasa = pd.read_csv('./Data/apod_clean_urls.csv')
nasa_train = nasa[nasa['split']=='train'].dropna(subset=['hdurl','explanation'])

# %%
len(nasa_train)
# Out:
# 7494

# %%
sample = nasa_train.sample(50,random_state =42)

# %%
import os

# Set HF_TOKEN in your environment before starting Jupyter (never commit tokens).
# https://huggingface.co/settings/tokens
if not os.environ.get("HF_TOKEN"):
    print("HF_TOKEN not set; Hub access may be rate-limited.")

# %%
flow,text_enc =train(sample,epochs=2,batch_size=8,device='cuda')
print("pipeline finished!")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#  50%|█████     | 1/2 [00:00<00:00,  1.12it/s]
# Epoch 1/2  loss=41822.3778
# 100%|██████████| 2/2 [00:01<00:00,  1.61it/s]
# Epoch 2/2  loss=218501.8665
# pipeline finished!

# %%
import torch

# %%
torch.save({
    "flow": flow.state_dict(),
    "text_enc": text_enc.state_dict()  
}, "model_bundle.pth")

# %%
nasa = pd.read_csv('./Data/apod_clean_urls.csv')

nasa_test = nasa[nasa['split']=='test'].dropna(
    subset=['hdurl','explanation']
)

# %%
len(nasa_test)
# Out:
# 1606

# %%
from evaluate import evaluate
from evaluatenew import evaluatenew

# %%
# ! python download_img.py
# Out:
#  85%|█████████████████████████████████      | 1361/1606 [12:41<05:04,  1.24s/it]❌ failed: 9051
#  89%|██████████████████████████████████▋    | 1428/1606 [13:40<01:47,  1.65it/s]❌ failed: 9539
#  89%|██████████████████████████████████▋    | 1429/1606 [13:40<01:24,  2.09it/s]❌ failed: 9540
#  89%|██████████████████████████████████▊    | 1431/1606 [13:41<01:20,  2.16it/s]❌ failed: 9552
# 100%|███████████████████████████████████████| 1606/1606 [16:11<00:00,  1.65it/s]
# ✅ Done downloading!

# %%
evaluate(nasa_test, flow, text_enc)
# Out:
# /home/che82/anaconda3/envs/cs766/lib/python3.11/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: Metric `Kernel Inception Distance` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# 100%|██████████| 101/101 [00:41<00:00,  2.45it/s]
# ===== Evaluation =====
# FID: 167.7391
# KID: 0.2211
# CLIP: 0.2352
# Log-Likelihood: -413831.5223
# (tensor(167.7391, device='cuda:0'),
#  tensor(0.2211, device='cuda:0'),
#  0.23515138531675434,
#  -413831.52225668123)

# %%
print("=== Conditional ===")
evaluatenew(nasa_test, flow, text_enc)

print("=== Unconditional ===")
evaluatenew(nasa_test, flow, text_enc, use_zero_context=True)
# Out:
# === Conditional ===
# 100%|██████████| 101/101 [00:40<00:00,  2.48it/s]
# ===== Evaluation =====
# FID: 167.6535
# KID: 0.2215
# CLIP: 0.2353
# Log-Likelihood: -413831.5223
# === Unconditional ===
# 100%|██████████| 101/101 [00:43<00:00,  2.34it/s]
# ===== Evaluation =====
# FID: 167.8148
# KID: 0.2211
# CLIP: 0.2256
# Log-Likelihood: -414503.2451
# (tensor(167.8148, device='cuda:0'),
#  tensor(0.2211, device='cuda:0'),
#  0.2256209873917079,
#  -414503.24514377705)

# %%
print("=== Conditional ===")
evaluatenew(nasa_test, flow, text_enc)

print("=== Unconditional ===")
evaluatenew(nasa_test, flow, text_enc, use_zero_context=True)
# Out:
# === Conditional ===
# 100%|██████████| 101/101 [00:40<00:00,  2.50it/s]
# ===== Evaluation =====
# FID: 168.4771
# KID: 0.2230
# CLIP: 0.2353
# Log-Likelihood: -413831.5223
# === Unconditional ===
# 100%|██████████| 101/101 [00:42<00:00,  2.36it/s]
# ===== Evaluation =====
# FID: 167.2277
# KID: 0.2197
# CLIP: 0.2256
# Log-Likelihood: -414503.2451
# (tensor(167.2277, device='cuda:0'),
#  tensor(0.2197, device='cuda:0'),
#  0.2255508372492523,
#  -414503.24514377705)

# %%
from evaluatenewtest import evaluatenewtest

# %%
print("=== Conditional ===")
evaluatenewtest(nasa_test, flow, text_enc)

print("=== Unconditional ===")
evaluatenewtest(nasa_test, flow, text_enc, use_zero_context=True)
# Out:
# === Conditional ===
# /home/che82/anaconda3/envs/cs766/lib/python3.11/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: Metric `Kernel Inception Distance` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# 100%|██████████| 101/101 [00:40<00:00,  2.49it/s]
# ===== Evaluation =====
# FID: 167.8044
# KID: 0.2234
# CLIP: 0.2354
# Log-Likelihood: -413831.5223
# === Unconditional ===
# 100%|██████████| 101/101 [00:42<00:00,  2.36it/s]
# ===== Evaluation =====
# FID: 168.0017
# KID: 0.2205
# CLIP: 0.2469
# Log-Likelihood: -414583.3944
# (tensor(168.0017, device='cuda:0'),
#  tensor(0.2205, device='cuda:0'),
#  0.2468754230159344,
#  -414583.3944224745)

# %%
print("=== Conditional ===")
evaluatenew(nasa_test, flow, text_enc)

print("=== Unconditional ===")
evaluatenew(nasa_test, flow, text_enc, use_zero_context=True)
# Out:
# === Conditional ===
# /home/che82/anaconda3/envs/cs766/lib/python3.11/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: Metric `Kernel Inception Distance` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# 100%|██████████| 101/101 [00:40<00:00,  2.51it/s]
# ===== Evaluation =====
# FID: 140.5016
# KID: 0.1667
# CLIP: 0.2306
# Log-Likelihood: -491773.4350
# === Unconditional ===
# 100%|██████████| 101/101 [00:41<00:00,  2.42it/s]
# ===== Evaluation =====
# FID: 141.2744
# KID: 0.1685
# CLIP: 0.2313
# Log-Likelihood: -491781.8343
# (tensor(141.2744, device='cuda:0'),
#  tensor(0.1685, device='cuda:0'),
#  0.23133918082359994,
#  -491781.8343034499)
